# %% [markdown]
# # Import Libraries and Datasets

# %%
import pandas as pd
import numpy as np
from functools import reduce
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn 
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from datetime import datetime as dt

# %%
# Importing excel files
company_incorporations_xls = pd.ExcelFile("Business Insights and Worforce Datasets - ADS/companyincorporationsvoluntarydissolutionsandcompulsorydissolutionsdataset030223.xlsx")
hr1_redundancies_xls = pd.ExcelFile("Business Insights and Worforce Datasets - ADS/hr1redundanciesdataset230223.xlsx")
online_job_adverts_xls = pd.ExcelFile("Business Insights and Worforce Datasets - ADS/onlinejobadvertestimatesdataset230223.xlsx")
uk_small_businesses_xls = pd.ExcelFile("Business Insights and Worforce Datasets - ADS/uksmallbusinesssalesandjobsdataset060123.xlsx")
vat_flash_xls = pd.ExcelFile("Business Insights and Worforce Datasets - ADS/vatflashdataset160223.xlsx")

#Importing CSV files
gdp_data = pd.read_csv("Consumer Behaviour Datasets - ADS/Figure_1__UK_Gross_domestic_product_(GDP)_is_estimated_to_have_fallen_by_0.5%_in_December_2022.csv")

# %%
#Reading in all excel files - specific sheets
company_incorporations_incorp = pd.read_excel(company_incorporations_xls, "Incorporations")
company_incorporations_vol = pd.read_excel(company_incorporations_xls, "Voluntary Dissolutions")
company_incorporations_comp = pd.read_excel(company_incorporations_xls, "Compulsory Dissolutions")

hr1_redundancies = pd.read_excel(hr1_redundancies_xls,"Potential redundancies")

online_job_adverts_category = pd.read_excel(online_job_adverts_xls,"Adverts by category Feb 2020 DD")
online_job_adverts_region = pd.read_excel(online_job_adverts_xls,"Adverts by region Feb 2020 DD")

uk_small_businesses_jobs = pd.read_excel(uk_small_businesses_xls,"Jobs by industry")
uk_small_businesses_sales = pd.read_excel(uk_small_businesses_xls,"Sales by industry")

vat_flash_turnover = pd.read_excel(vat_flash_xls, "Turnover SA MoM")
vat_flash_exp = pd.read_excel(vat_flash_xls, "Expenditure SA MoM")
vat_flash_newreporters = pd.read_excel(vat_flash_xls, "New reporters SA")
vat_flash_records = pd.read_excel(vat_flash_xls, "Record type SA")

# %% [markdown]
# # Creating a class to help clean data

# %%
class clean:
    
    def __init__ (self,df,query_dataset=False,setheader= False,header_int=0,droprows=False,rows_to_drop=[],
                  drop_cols=False,columns_to_drop=[],to_transpose=False,to_datetime=False,dayfirst=False,nancolumn=False,columns_to_keep=[],
                  converttopct=False,converttonan=False,rename_cols=False,to_append='',replace_nan=False):
        
        self.df = df
        self.query_dataset= query_dataset
        self.to_transpose = to_transpose
        self.setheader = setheader
        self.header_int = header_int
        self.droprows = droprows
        self.rows_to_drop=rows_to_drop
        self.drop_cols=drop_cols
        self.columns_to_drop=columns_to_drop
        self.to_datetime = to_datetime
        self.dayfirst=dayfirst
        self.converttopct=converttopct
        self.converttonan=converttonan
        self.nancolumn=nancolumn
        self.columns_to_keep=columns_to_keep
        self.renamecols=rename_cols
        self.toappend = to_append
        self.replace_nan = replace_nan
    
    def getnewheaders(self):
        return self.df.columns
    
    def agg_column(self):
        cols = self.getnewheaders()
        if len(cols) == 1:
            column_list = self.getnewheaders()
            agg_column = column_list[0]
        else:
            agg_column = self.getnewheaders()
        return agg_column
    
       
    def convert_to_pct(self):
        aggregate_col = self.agg_column()
        if type(aggregate_col) == str:
            for i,index in enumerate(self.df.index):
                my_str = str(self.df[aggregate_col][i])
                my_str = my_str[:-1]
                my_str = pd.to_numeric(my_str)
                self.df.loc[self.df.index == index,aggregate_col] = my_str/100
                
        else:
            column_list = self.agg_column()
            for label in column_list:
                for i,index in enumerate(self.df.index):
                    my_str = str(self.df[label][i])
                    my_str = my_str[:-1]
                    my_str = pd.to_numeric(my_str)
                    self.df.loc[self.df.index == index,label] = my_str/100
                    
                    
    def convert_to_nan(self):
        aggregate_col = self.agg_column()
        if type(aggregate_col) == str:
            self.df[aggregate_col] = pd.to_numeric(self.df[aggregate_col],errors='coerce')
                
        else:
            column_list = self.agg_column()
            for label in column_list:
                self.df[label] = pd.to_numeric(self.df[label],errors='coerce')
            
                    
    def resampleandchangeformat(self):
        self.df = self.df.resample('M',kind='timestamp').mean()
        self.df.index = self.df.index.strftime('%b %Y')
        return self.df

                
    def final_clean(self):
        if self.query_dataset == True:
            self.df = self.df.query("Name == 'United Kingdom'")
        if self.setheader == True:
            header_array = self.df.iloc[self.header_int].ravel()
            self.df.set_axis(header_array,axis=1,inplace=True)
        if self.droprows == True:
            self.df.drop(self.rows_to_drop,inplace=True)
        self.df.set_index(self.df.columns[0] ,inplace=True)
        self.df.index.names = ['Date']
        if self.drop_cols==True:
             self.df.drop(columns=self.columns_to_drop,inplace=True)
        if self.to_transpose == True:
            self.df = self.df.T
        if self.to_datetime == True and self.dayfirst==True:
            self.df.index = pd.to_datetime(self.df.index,dayfirst=True)
        else:
            self.df.index = pd.to_datetime(self.df.index)
        if self.replace_nan == True:
            self.df.iloc[:,0] = self.df.iloc[:,0].replace(np.nan, '0%')
        if self.nancolumn==True:
            self.df = self.df.loc[:,self.columns_to_keep]
        if self.converttopct==True:
            self.convert_to_pct()
        if self.converttonan==True:
            self.convert_to_nan()
        self.df= self.resampleandchangeformat()
        a = dt.strptime(self.df.index[0], '%b %Y')
        b = dt.strptime('Jan 2020', '%b %Y')
        if a < b:
            self.df = self.df['Jan 2020':'Dec 2022']
        else:
            self.df = self.df[self.df.index[0]:]
        if self.renamecols == True:
            column_list = self.getnewheaders()
            for label in column_list:
                to_append = '_' + self.toappend
                new_column_name = str(label)+to_append
                self.df.rename(columns={label:new_column_name},inplace=True)
        return self.df

# %% [markdown]
# # Dataset cleaning

# %%
#Before cleaning
company_incorporations_incorp.head()
# Out:
#   Number of weekly company incorporation applications recorded by Companies House[note 1]  \
# 0                 This worksheet contains one table.
# 1                         [x] = Data are unavailable
# 2                                    Companies House
# 3                                     Week ending to
# 4                                2019-01-04 00:00:00
#
#   Unnamed: 1      Unnamed: 2
# 0        NaN             NaN
# 1        NaN             NaN
# 2        NaN             NaN
# 3     Weekly  4 week average
# 4       5857             [x]

# %%
#Setting required variables
cii_header=3
cii_droprows = [0,1,2,3]
cii_dropcols = ['4 week average']

#class instance
dataset_cleaning = clean(company_incorporations_incorp,setheader= True,header_int=cii_header,droprows=True,rows_to_drop=cii_droprows,
                  drop_cols=True,columns_to_drop=cii_dropcols,rename_cols=True,to_append='Incorporations')
company_incorporations_incorp = dataset_cleaning.final_clean()

#After cleaning
company_incorporations_incorp.head()
# Out:
#           Weekly_Incorporations
# Date
# Jan 2020               12162.20
# Feb 2020               14276.00
# Mar 2020               12359.75
# Apr 2020                9041.25
# May 2020               12878.40

# %%
#Before cleaning
company_incorporations_vol.head()
# Out:
#   Number of weekly company voluntary dissolution applications recorded by Companies House [note 1][note 2]  \
# 0  This worksheet contains one table. Some cells ...
# 1                         [x] = Data are unavailable
# 2                                    Companies House
# 3                                     Week ending to
# 4                                2019-01-04 00:00:00
#
#   Unnamed: 1      Unnamed: 2
# 0        NaN             NaN
# 1        NaN             NaN
# 2        NaN             NaN
# 3     Weekly  4 week average
# 4       3095             [x]

# %%
#Setting required variables
civ_header=3
civ_droprows = [0,1,2,3]
civ_dropcols = ['4 week average']

#class instance
dataset_cleaning = clean(company_incorporations_vol,setheader= True,header_int=civ_header,droprows=True,rows_to_drop=civ_droprows,
                  drop_cols=True,columns_to_drop=cii_dropcols,rename_cols=True,to_append='Voluntary_Dissolutions')
company_incorporations_vol = dataset_cleaning.final_clean()

#After cleaning
company_incorporations_vol.head()
# Out:
#           Weekly_Voluntary_Dissolutions
# Date
# Jan 2020                        5901.40
# Feb 2020                        6094.75
# Mar 2020                        5683.50
# Apr 2020                        4183.50
# May 2020                        4476.00

# %%
#Before cleaning
company_incorporations_comp.head()
# Out:
#   Number of weekly compulsory company dissolutions recorded by Companies House  [note 3][note 4][note 5]  \
# 0                 This worksheet contains one table.
# 1                         [x] = Data are unavailable
# 2                                    Companies House
# 3                                     Week ending to
# 4                                2018-01-02 00:00:00
#
#   Unnamed: 1      Unnamed: 2  Unnamed: 3
# 0        NaN             NaN         NaN
# 1        NaN             NaN         NaN
# 2        NaN             NaN         NaN
# 3     Weekly  4 week average  Cumulative
# 4      10164             [x]       10164

# %%
#Setting required variables
cic_header=3
cic_droprows = [0,1,2,3]
cic_dropcols = ['4 week average','Cumulative']

#class instance
dataset_cleaning = clean(company_incorporations_comp,setheader= True,header_int=cic_header,droprows=True,rows_to_drop=cic_droprows,
                  drop_cols=True,columns_to_drop=cic_dropcols,converttonan=True,rename_cols=True,to_append='Compulsory_Dissolutions')
company_incorporations_comp = dataset_cleaning.final_clean()

#After cleaning
company_incorporations_comp.head()
# Out:
#           Weekly_Compulsory_Dissolutions
# Date
# Jan 2020                         5827.50
# Feb 2020                         8851.00
# Mar 2020                         7569.00
# Apr 2020                         2925.25
# May 2020                            5.50

# %%
#Before cleaning
hr1_redundancies.head()
# Out:
#   Number of potential redundancies from HR1 forms and number of employers proposing redundancies  \
# 0                                               Date
# 1                                2019-04-07 00:00:00
# 2                                2019-04-14 00:00:00
# 3                                2019-04-21 00:00:00
# 4                                2019-04-28 00:00:00
#
#                Unnamed: 1                        Unnamed: 2  \
# 0  Potential redundancies  Employers proposing redundancies
# 1                    3115                                62
# 2                       *                                58
# 3                    2409                                41
# 4                    3291                                57
#
#                                       Unnamed: 3  \
# 0  Potential redundancies 4-week rolling average
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                                           Unnamed: 4  \
# 0  Potential redundancies \n4-week rolling averag...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 5  \
# 0  Employers proposing redundancies\n4-week rolli...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                        .1   .2   .3  \
# 0  Employers proposing redundancies\n4-week rolli...            NaN
# 1                                                NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN
# 3                                                NaN  NaN  NaN  NaN
# 4                                                NaN  NaN  NaN  NaN
#
#   Unnamed: 10  Unnamed: 11 Unnamed: 12
# 0                      NaN
# 1         NaN          NaN         NaN
# 2         NaN          NaN         NaN
# 3         NaN          NaN         NaN
# 4         NaN          NaN         NaN

# %%
#Setting required variables
hr_header=0
hr_droprows = [0]
hr_dropcols = ['Potential redundancies 4-week rolling average','Potential redundancies \n4-week rolling average \n(indexed: 100 = weekly average from week ending 21 Apr 19 to week ending 23 Feb 20)','Employers proposing redundancies\n4-week rolling average','Employers proposing redundancies\n4-week rolling average (indexed: 100 = weekly average from week ending 21 Apr 19 to week ending 23 Feb 20)']

#class instance
dataset_cleaning = clean(hr1_redundancies,setheader= True,header_int=hr_header,droprows=True,rows_to_drop=hr_droprows,drop_cols=True,columns_to_drop=hr_dropcols,converttonan=True,nancolumn=True,columns_to_keep=['Potential redundancies','Employers proposing redundancies'])
hr1_redundancies = dataset_cleaning.final_clean()

#After cleaning
hr1_redundancies.head()
# Out:
#           Potential redundancies  Employers proposing redundancies
# Date
# Jan 2020                 5198.25                             50.25
# Feb 2020                 6139.00                             73.00
# Mar 2020                 8397.80                             77.80
# Apr 2020                10488.50                             58.50
# May 2020                17462.80                            141.40

# %%
#Before cleaning
online_job_adverts_category.head()
# Out:
#   Adverts by category indexed with February 2020 for deduplicated job adverts  \
# 0                   Index 100: average February 2020
# 1  This worksheet contains one table. Some cells ...
# 2  Some cells in the notes column of this table a...
# 3  Colour is used for emphasis in this table. The...
# 4                                     Source: Adzuna
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 2        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 3        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 4        NaN        NaN        NaN  ...         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 31
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 32 columns]

# %%
#Setting required variables
ojac_header= 5
ojac_droprows = [0,1,2,3,4,5]
ojac_dropcols = ['All industries','Notes']

#class instance
dataset_cleaning = clean(online_job_adverts_category,setheader=True,header_int=ojac_header,droprows=True,rows_to_drop=ojac_droprows,
                         drop_cols=True,columns_to_drop=ojac_dropcols,rename_cols=True,to_append='category')
online_job_adverts_category = dataset_cleaning.final_clean()

#After cleaning
online_job_adverts_category.head()
# Out:
#           Accounting / Finance_category  \
# Date
# Jan 2020                         93.060
# Feb 2020                        100.025
# Mar 2020                         96.125
# Apr 2020                         53.000
# May 2020                         30.900
#
#           Admin / clerical / secretarial_category  \
# Date
# Jan 2020                                   92.180
# Feb 2020                                  100.000
# Mar 2020                                   88.425
# Apr 2020                                   37.225
# May 2020                                   18.740
#
#           Catering and hospitality_category  Charity / voluntary_category  \
# Date
# Jan 2020                             96.120                        91.440
# Feb 2020                            100.000                       100.000
# Mar 2020                             72.925                        88.650
# Apr 2020                             24.650                        42.675
# May 2020                             13.580                        28.160
#
#           Construction / trades_category  \
# Date
# Jan 2020                          92.380
# Feb 2020                          99.975
# Mar 2020                          95.750
# Apr 2020                          48.925
# May 2020                          26.720
#
#           Creative / design / arts & media_category  \
# Date
# Jan 2020                                     96.820
# Feb 2020                                     99.975
# Mar 2020                                     90.725
# Apr 2020                                     54.175
# May 2020                                     37.980
#
#           Customer service / support_category  Domestic help_category  \
# Date
# Jan 2020                               93.960                  99.060
# Feb 2020                              100.000                 100.000
# Mar 2020                               89.575                 103.525
# Apr 2020                               46.375                 113.775
# May 2020                               26.000                  80.620
#
#           Education_category  Energy / oil & gas_category  ...  \
# Date                                                       ...
# Jan 2020              89.320                      106.240  ...
# Feb 2020             100.000                       99.975  ...
# Mar 2020              99.900                       87.800  ...
# Apr 2020              78.675                       38.150  ...
# May 2020              61.400                       25.440  ...
#
#           Other / general_category  Part-time / weekend_category  \
# Date
# Jan 2020                   120.340                        94.560
# Feb 2020                   100.025                       100.000
# Mar 2020                    98.200                        85.425
# Apr 2020                    61.275                        45.650
# May 2020                    41.820                        33.700
#
#           Property_category  Wholesale and retail_category  Sales_category  \
# Date
# Jan 2020             89.360                         96.280          92.420
# Feb 2020            100.025                         99.975         100.025
# Mar 2020             93.400                         88.675          88.225
# Apr 2020             45.575                         43.400          38.775
# May 2020             28.700                         28.680          17.980
#
#           Scientific / QA_category  \
# Date
# Jan 2020                    91.280
# Feb 2020                   100.025
# Mar 2020                    94.225
# Apr 2020                    64.925
# May 2020                    53.360
#
#           Transport / logistics / warehouse_category  \
# Date
# Jan 2020                                     109.960
# Feb 2020                                     100.025
# Mar 2020                                     102.700
# Apr 2020                                      58.050
# May 2020                                      34.360
#
#           Travel / tourism_category  Unknown_category  \
# Date
# Jan 2020                    111.060           126.520
# Feb 2020                    100.025           100.000
# Mar 2020                     98.575           142.875
# Apr 2020                     48.550            37.775
# May 2020                     25.700            21.540
#
#           Healthcare and Social care_category
# Date
# Jan 2020                               94.860
# Feb 2020                               99.975
# Mar 2020                               96.300
# Apr 2020                               92.225
# May 2020                               85.660
#
# [5 rows x 29 columns]

# %%
#Before cleaning
online_job_adverts_region.head()
# Out:
#   Adverts by region indexed with February 2020 for deduplicated job adverts  \
# 0                   Index 100: average February 2020
# 1  This worksheet contains one table. Some cells ...
# 2  Some cells in the notes column of this table a...
# 3  Colour is used for emphasis in this table. The...
# 4                                     Source: Adzuna
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN        NaN         NaN         NaN         NaN
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
#Setting required variables
ojar_header= 5
ojar_droprows = [0,1,2,3,4,5]
ojar_dropcols = ['All Regions','Notes']

#class instance
dataset_cleaning = clean(online_job_adverts_region,setheader=True,header_int=ojar_header,droprows=True,rows_to_drop=ojar_droprows,
                         drop_cols=True,columns_to_drop=ojar_dropcols,rename_cols=True,to_append='region')
online_job_adverts_region = dataset_cleaning.final_clean()

#After cleaning
online_job_adverts_region.head()
# Out:
#           East Midlands_region  East of England_region  London_region  \
# Date
# Jan 2020                94.280                   95.64         93.960
# Feb 2020               100.025                  100.00        100.000
# Mar 2020                91.375                   93.15         91.575
# Apr 2020                56.900                   58.00         56.275
# May 2020                39.200                   40.58         37.240
#
#           North East_region  North West_region  Northern Ireland_region  \
# Date
# Jan 2020             93.520             93.300                   85.540
# Feb 2020             99.975            100.000                  100.000
# Mar 2020             89.800             92.975                   84.175
# Apr 2020             58.350             57.450                   56.600
# May 2020             41.520             39.120                   43.840
#
#           Scotland_region  South East_region  South West_region  \
# Date
# Jan 2020           88.440             94.860             95.280
# Feb 2020           99.975            100.000            100.025
# Mar 2020           88.150             92.475             91.950
# Apr 2020           48.575             55.850             55.875
# May 2020           36.180             37.460             39.500
#
#           Unknown_region  Wales_region  West Midlands_region  \
# Date
# Jan 2020         103.000         87.46                96.200
# Feb 2020         100.000        100.00               100.000
# Mar 2020         105.175         81.80                94.625
# Apr 2020          73.175         52.05                56.900
# May 2020          61.460         36.22                37.160
#
#           Yorkshire and The Humber_region  England_region
# Date
# Jan 2020                            95.10          94.620
# Feb 2020                           100.00          99.975
# Mar 2020                            92.80          92.350
# Apr 2020                            56.35          56.625
# May 2020                            37.82          38.240

# %%
#Before cleaning
uk_small_businesses_jobs.head()
# Out:
#                    UK small business jobs     Unnamed: 1                \
# 0  Index (100 = equivalent month of 2019)            NaN           NaN
# 1                                   Month  Manufacturing  Construction
# 2                     2019-01-01 00:00:00            100           100
# 3                     2019-02-01 00:00:00            100           100
# 4                     2019-03-01 00:00:00            100           100
#
#              .1                       Unnamed: 4  \
# 0           NaN                              NaN
# 1  Retail Trade  Accommodation and Food Services
# 2           100                              100
# 3           100                              100
# 4           100                              100
#
#                                  Unnamed: 5  \
# 0                                       NaN
# 1  Information Media and Telecommunications
# 2                                       100
# 3                                       100
# 4                                       100
#
#                                 Unnamed: 6  \
# 0                                      NaN
# 1  Rental, Hiring and Real Estate Services
# 2                                      100
# 3                                      100
# 4                                      100
#
#                                         Unnamed: 7  \
# 0                                              NaN
# 1  Professional, Scientific and Technical Services
# 2                                              100
# 3                                              100
# 4                                              100
#
#                             Unnamed: 8      Unnamed: 9  \
# 0                                                  NaN
# 1  Administrative and Support Services  Other Services
# 2                                  100             100
# 3                                  100             100
# 4                                  100             100
#
#                          Unnamed: 10
# 0                                NaN
# 1  Health Care and Social Assistance
# 2                                100
# 3                                100
# 4                                100

# %%
#Setting required variables
sbj_header=1
sbj_droprows = [0,1]

#class instance
dataset_cleaning = clean(uk_small_businesses_jobs,setheader=True,header_int=sbj_header,droprows=True,
                         rows_to_drop=sbj_droprows,rename_cols=True,to_append='Jobs')
uk_small_businesses_jobs = dataset_cleaning.final_clean()

#After cleaning
uk_small_businesses_jobs.head()
# Out:
#           Manufacturing_Jobs  Construction_Jobs  Retail Trade_Jobs  \
# Date
# Jan 2020               107.4               99.5              100.2
# Feb 2020               105.6               97.2               99.4
# Mar 2020                99.8               97.4               98.9
# Apr 2020                82.3               73.8               76.9
# May 2020                79.0               73.9               78.1
#
#           Accommodation and Food Services_Jobs  \
# Date
# Jan 2020                                  98.1
# Feb 2020                                  98.2
# Mar 2020                                  87.1
# Apr 2020                                  44.5
# May 2020                                  36.9
#
#           Information Media and Telecommunications_Jobs  \
# Date
# Jan 2020                                          110.9
# Feb 2020                                          110.4
# Mar 2020                                          110.7
# Apr 2020                                          100.7
# May 2020                                           97.8
#
#           Rental, Hiring and Real Estate Services_Jobs  \
# Date
# Jan 2020                                         101.2
# Feb 2020                                         101.1
# Mar 2020                                          94.8
# Apr 2020                                          66.4
# May 2020                                          62.6
#
#           Professional, Scientific and Technical Services_Jobs  \
# Date
# Jan 2020                                              105.0
# Feb 2020                                              104.6
# Mar 2020                                              102.1
# Apr 2020                                               90.4
# May 2020                                               88.0
#
#           Administrative and Support Services_Jobs  Other Services_Jobs  \
# Date
# Jan 2020                                     103.7                101.9
# Feb 2020                                     101.0                101.2
# Mar 2020                                      95.9                 93.0
# Apr 2020                                      66.4                 75.4
# May 2020                                      74.5                 69.7
#
#           Health Care and Social Assistance_Jobs
# Date
# Jan 2020                                   109.7
# Feb 2020                                   110.7
# Mar 2020                                   101.0
# Apr 2020                                    80.0
# May 2020                                    72.3

# %%
#Before cleaning
uk_small_businesses_sales.head()
# Out:
#                   UK small business sales     Unnamed: 1    Unnamed: 2  \
# 0  Index (100 = equivalent month of 2019)            NaN           NaN
# 1                                   Month  Manufacturing  Construction
# 2                     2019-01-01 00:00:00            100           100
# 3                     2019-02-01 00:00:00            100           100
# 4                     2019-03-01 00:00:00            100           100
#
#                                       Unnamed: 4  \
# 0           NaN                              NaN
# 1  Retail Trade  Accommodation and Food Services
# 2           100                              100
# 3           100                              100
# 4           100                              100
#
#                                  Unnamed: 5  \
# 0                                       NaN
# 1  Information Media and Telecommunications
# 2                                       100
# 3                                       100
# 4                                       100
#
#                                 Unnamed: 6  \
# 0                                      NaN
# 1  Rental, Hiring and Real Estate Services
# 2                                      100
# 3                                      100
# 4                                      100
#
#                                         Unnamed: 7  \
# 0                                              NaN
# 1  Professional, Scientific and Technical Services
# 2                                              100
# 3                                              100
# 4                                              100
#
#                                     .1      Unnamed: 9  \
# 0                                  NaN             NaN
# 1  Administrative and Support Services  Other Services
# 2                                  100             100
# 3                                  100             100
# 4                                  100             100
#
#                          Unnamed: 10
# 0                                NaN
# 1  Health Care and Social Assistance
# 2                                100
# 3                                100
# 4                                100

# %%
#Setting required variables
sbs_header=1
sbs_droprows = [0,1]

#class instance
dataset_cleaning = clean(uk_small_businesses_sales,setheader=True,header_int=sbs_header,
                         droprows=True,rows_to_drop=sbs_droprows,rename_cols=True,to_append='Sales')
uk_small_businesses_sales = dataset_cleaning.final_clean()

#After cleaning
uk_small_businesses_sales.head()
# Out:
#           Manufacturing_Sales  Construction_Sales  Retail Trade_Sales  \
# Date
# Jan 2020                105.1               104.3               106.5
# Feb 2020                105.8               103.4               107.8
# Mar 2020                 97.4               102.2               100.6
# Apr 2020                 67.5                56.4                86.6
# May 2020                 72.2                59.1                91.9
#
#           Accommodation and Food Services_Sales  \
# Date
# Jan 2020                                  105.4
# Feb 2020                                  104.3
# Mar 2020                                   65.7
# Apr 2020                                   39.2
# May 2020                                   39.5
#
#           Information Media and Telecommunications_Sales  \
# Date
# Jan 2020                                           112.1
# Feb 2020                                           108.8
# Mar 2020                                           110.5
# Apr 2020                                            87.8
# May 2020                                            82.5
#
#           Rental, Hiring and Real Estate Services_Sales  \
# Date
# Jan 2020                                          108.7
# Feb 2020                                          105.2
# Mar 2020                                           96.6
# Apr 2020                                           76.7
# May 2020                                           74.7
#
#           Professional, Scientific and Technical Services_Sales  \
# Date
# Jan 2020                                              108.7
# Feb 2020                                              106.0
# Mar 2020                                              105.4
# Apr 2020                                               84.7
# May 2020                                               77.0
#
#           Administrative and Support Services_Sales  Other Services_Sales  \
# Date
# Jan 2020                                      103.1                 105.4
# Feb 2020                                      102.0                 110.0
# Mar 2020                                       97.0                  92.6
# Apr 2020                                       68.2                  69.2
# May 2020                                       63.7                  63.9
#
#           Health Care and Social Assistance_Sales
# Date
# Jan 2020                                    109.6
# Feb 2020                                    109.3
# Mar 2020                                    106.4
# Apr 2020                                     95.6
# May 2020                                     90.8

# %%
#Before cleaning
vat_flash_turnover.head()
# Out:
#   Diffusion index, turnover, day 7, seasonally adjusted, Month on Month  \
# 0                 This worksheet contains one table.
# 1                         [x] = Data are unavailable
# 2      [c] = Data have been supressed for disclosure
# 3                     Office for National Statistics
# 4                                               Date
#
#     Unnamed: 1        Unnamed: 2      Unnamed: 3  \
# 0          NaN               NaN             NaN
# 1          NaN               NaN             NaN
# 2          NaN               NaN             NaN
# 3          NaN               NaN             NaN
# 4  Total (A-T)  Production (B-E)  Services (G-T)
#
#                               Unnamed: 4                Unnamed: 5  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4  Agriculture, forestry and fishing (A)  Mining and quarrying (B)
#
#           Unnamed: 6                           Unnamed: 7  \
# 0                NaN                                  NaN
# 1                NaN                                  NaN
# 2                NaN                                  NaN
# 3                NaN                                  NaN
# 4  Manufacturing (C)  Electricity, gas, steam and air (D)
#
#                         Unnamed: 8        Unnamed: 9  ...  \
# 0                              NaN               NaN  ...
# 1                              NaN               NaN  ...
# 2                              NaN               NaN  ...
# 3                              NaN               NaN  ...
# 4  Water supply, sewerage, etc (E)  Construction (F)  ...
#
#                          Unnamed: 13                             Unnamed: 14  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4  Information and communication (J)  Financial and insurance activities (K)
#
#                   Unnamed: 15  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  Real estate activities (L)
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Professional, scientific and technical activit...
#
#                                  Unnamed: 17  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  Administrative and support activities (N)
#
#                              Unnamed: 18    Unnamed: 19  \
# 0                                    NaN            NaN
# 1                                    NaN            NaN
# 2                                    NaN            NaN
# 3                                    NaN            NaN
# 4  Public administration and defence (O)  Education (P)
#
#                         Unnamed: 20                             Unnamed: 21  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4  Human health and social work (Q)  Arts, entertainmant and recreation (R)
#
#                     Unnamed: 22
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  Other service activities (S)
#
# [5 rows x 23 columns]

# %%
#Setting required variables
vft_header=4
vft_droprows = [0,1,2,3,4]
vft_dropcols = ['Total (A-T)']

#class instance
dataset_cleaning = clean(vat_flash_turnover,setheader=True,header_int=vft_header,droprows=True,rows_to_drop=vft_droprows,
                         drop_cols=True,columns_to_drop=vft_dropcols,converttonan=True,rename_cols=True,to_append='Turnover')
vat_flash_turnover = dataset_cleaning.final_clean()

#After cleaning
vat_flash_turnover.head()
# Out:
#           Production (B-E)_Turnover  Services (G-T)_Turnover  \
# Date
# Jan 2020                       0.02                     0.00
# Feb 2020                      -0.02                    -0.05
# Mar 2020                      -0.26                    -0.18
# Apr 2020                      -0.30                    -0.19
# May 2020                       0.06                    -0.09
#
#           Agriculture, forestry and fishing (A)_Turnover  \
# Date
# Jan 2020                                            0.03
# Feb 2020                                            0.00
# Mar 2020                                           -0.02
# Apr 2020                                           -0.09
# May 2020                                            0.05
#
#           Mining and quarrying (B)_Turnover  Manufacturing (C)_Turnover  \
# Date
# Jan 2020                                NaN                        0.04
# Feb 2020                                NaN                       -0.03
# Mar 2020                                NaN                       -0.30
# Apr 2020                                NaN                       -0.28
# May 2020                                NaN                        0.06
#
#           Electricity, gas, steam and air (D)_Turnover  \
# Date
# Jan 2020                                           NaN
# Feb 2020                                           NaN
# Mar 2020                                           NaN
# Apr 2020                                           NaN
# May 2020                                           NaN
#
#           Water supply, sewerage, etc (E)_Turnover  Construction (F)_Turnover  \
# Date
# Jan 2020                                       NaN                       0.04
# Feb 2020                                       NaN                      -0.01
# Mar 2020                                       NaN                      -0.17
# Apr 2020                                       NaN                      -0.31
# May 2020                                       NaN                       0.04
#
#           Wholesale and retail; repair of motor vehicles (G)_Turnover  \
# Date
# Jan 2020                                               0.03
# Feb 2020                                              -0.11
# Mar 2020                                              -0.06
# Apr 2020                                              -0.20
# May 2020                                               0.09
#
#           Transport and storage (H)_Turnover  ...  \
# Date                                          ...
# Jan 2020                                0.06  ...
# Feb 2020                               -0.01  ...
# Mar 2020                               -0.43  ...
# Apr 2020                               -0.35  ...
# May 2020                               -0.18  ...
#
#           Information and communication (J)_Turnover  \
# Date
# Jan 2020                                        0.02
# Feb 2020                                       -0.03
# Mar 2020                                       -0.18
# Apr 2020                                       -0.24
# May 2020                                        0.05
#
#           Financial and insurance activities (K)_Turnover  \
# Date
# Jan 2020                                              NaN
# Feb 2020                                              NaN
# Mar 2020                                              NaN
# Apr 2020                                              NaN
# May 2020                                              NaN
#
#           Real estate activities (L)_Turnover  \
# Date
# Jan 2020                                 0.03
# Feb 2020                                -0.05
# Mar 2020                                -0.12
# Apr 2020                                -0.13
# May 2020                                -0.18
#
#           Professional, scientific and technical activities (M)_Turnover  \
# Date
# Jan 2020                                              -0.03
# Feb 2020                                              -0.06
# Mar 2020                                              -0.06
# Apr 2020                                              -0.22
# May 2020                                              -0.06
#
#           Administrative and support activities (N)_Turnover  \
# Date
# Jan 2020                                               0.00
# Feb 2020                                              -0.04
# Mar 2020                                              -0.28
# Apr 2020                                              -0.24
# May 2020                                               0.01
#
#           Public administration and defence (O)_Turnover  \
# Date
# Jan 2020                                             NaN
# Feb 2020                                             NaN
# Mar 2020                                             NaN
# Apr 2020                                             NaN
# May 2020                                             NaN
#
#           Education (P)_Turnover  Human health and social work (Q)_Turnover  \
# Date
# Jan 2020                    0.00                                      -0.17
# Feb 2020                   -0.06                                      -0.02
# Mar 2020                   -0.43                                      -0.06
# Apr 2020                   -0.17                                       0.18
# May 2020                    0.00                                      -0.36
#
#           Arts, entertainmant and recreation (R)_Turnover  \
# Date
# Jan 2020                                            -0.05
# Feb 2020                                            -0.06
# Mar 2020                                            -0.18
# Apr 2020                                            -0.44
# May 2020                                            -0.09
#
#           Other service activities (S)_Turnover
# Date
# Jan 2020                                  -0.06
# Feb 2020                                   0.09
# Mar 2020                                  -0.05
# Apr 2020                                  -0.48
# May 2020                                   0.03
#
# [5 rows x 21 columns]

# %%
#Before cleaning
vat_flash_exp.head()
# Out:
#   Diffusion index, expenditure, day 7, seasonally adjusted, Month on Month  \
# 0                 This worksheet contains one table.
# 1                         [x] = Data are unavailable
# 2      [c] = Data have been supressed for disclosure
# 3                     Office for National Statistics
# 4                                               Date
#
#     Unnamed: 1        Unnamed: 2      Unnamed: 3  \
# 0          NaN               NaN             NaN
# 1          NaN               NaN             NaN
# 2          NaN               NaN             NaN
# 3          NaN               NaN             NaN
# 4  Total (A-T)  Production (B-E)  Services (G-T)
#
#                               Unnamed: 4                Unnamed: 5  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4  Agriculture, forestry and fishing (A)  Mining and quarrying (B)
#
#           Unnamed: 6                           Unnamed: 7  \
# 0                NaN                                  NaN
# 1                NaN                                  NaN
# 2                NaN                                  NaN
# 3                NaN                                  NaN
# 4  Manufacturing (C)  Electricity, gas, steam and air (D)
#
#                         Unnamed: 8        Unnamed: 9  ...  \
# 0                              NaN               NaN  ...
# 1                              NaN               NaN  ...
# 2                              NaN               NaN  ...
# 3                              NaN               NaN  ...
# 4  Water supply, sewerage, etc (E)  Construction (F)  ...
#
#                          Unnamed: 13                             Unnamed: 14  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4  Information and communication (J)  Financial and insurance activities (K)
#
#                   Unnamed: 15  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  Real estate activities (L)
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Professional, scientific and technical activit...
#
#                                  Unnamed: 17  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  Administrative and support activities (N)
#
#                              Unnamed: 18    Unnamed: 19  \
# 0                                    NaN            NaN
# 1                                    NaN            NaN
# 2                                    NaN            NaN
# 3                                    NaN            NaN
# 4  Public administration and defence (O)  Education (P)
#
#                         Unnamed: 20                             Unnamed: 21  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4  Human health and social work (Q)  Arts, entertainmant and recreation (R)
#
#                     Unnamed: 22
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  Other service activities (S)
#
# [5 rows x 23 columns]

# %%
#Setting required variables
vfe_header=4
vfe_droprows = [0,1,2,3,4]
vfe_dropcols = ['Total (A-T)']

#class instance
dataset_cleaning = clean(vat_flash_exp,setheader=True,header_int=vfe_header,droprows=True,rows_to_drop=vfe_droprows,
                         drop_cols=True,columns_to_drop=vfe_dropcols,converttonan=True,rename_cols=True,to_append='Exp')
vat_flash_exp = dataset_cleaning.final_clean()

#After cleaning
vat_flash_exp.head()
# Out:
#           Production (B-E)_Exp  Services (G-T)_Exp  \
# Date
# Jan 2020                  0.06                0.03
# Feb 2020                 -0.01               -0.01
# Mar 2020                 -0.12               -0.12
# Apr 2020                 -0.22               -0.24
# May 2020                  0.04                0.00
#
#           Agriculture, forestry and fishing (A)_Exp  \
# Date
# Jan 2020                                       0.05
# Feb 2020                                       0.01
# Mar 2020                                       0.00
# Apr 2020                                       0.02
# May 2020                                       0.00
#
#           Mining and quarrying (B)_Exp  Manufacturing (C)_Exp  \
# Date
# Jan 2020                           NaN                   0.05
# Feb 2020                           NaN                   0.00
# Mar 2020                           NaN                  -0.14
# Apr 2020                           NaN                  -0.27
# May 2020                           NaN                   0.06
#
#           Electricity, gas, steam and air (D)_Exp  \
# Date
# Jan 2020                                     0.13
# Feb 2020                                    -0.07
# Mar 2020                                    -0.01
# Apr 2020                                     0.10
# May 2020                                    -0.11
#
#           Water supply, sewerage, etc (E)_Exp  Construction (F)_Exp  \
# Date
# Jan 2020                                  NaN                  0.08
# Feb 2020                                  NaN                  0.00
# Mar 2020                                  NaN                 -0.19
# Apr 2020                                  NaN                 -0.28
# May 2020                                  NaN                  0.08
#
#           Wholesale and retail; repair of motor vehicles (G)_Exp  \
# Date
# Jan 2020                                               0.02
# Feb 2020                                              -0.04
# Mar 2020                                              -0.05
# Apr 2020                                              -0.26
# May 2020                                               0.06
#
#           Transport and storage (H)_Exp  ...  \
# Date                                     ...
# Jan 2020                          -0.03  ...
# Feb 2020                          -0.03  ...
# Mar 2020                          -0.34  ...
# Apr 2020                          -0.52  ...
# May 2020                          -0.06  ...
#
#           Information and communication (J)_Exp  \
# Date
# Jan 2020                                  -0.03
# Feb 2020                                   0.03
# Mar 2020                                  -0.09
# Apr 2020                                  -0.23
# May 2020                                   0.01
#
#           Financial and insurance activities (K)_Exp  \
# Date
# Jan 2020                                         NaN
# Feb 2020                                         NaN
# Mar 2020                                         NaN
# Apr 2020                                         NaN
# May 2020                                         NaN
#
#           Real estate activities (L)_Exp  \
# Date
# Jan 2020                            0.01
# Feb 2020                            0.05
# Mar 2020                            0.03
# Apr 2020                           -0.24
# May 2020                           -0.01
#
#           Professional, scientific and technical activities (M)_Exp  \
# Date
# Jan 2020                                               0.11
# Feb 2020                                              -0.04
# Mar 2020                                              -0.18
# Apr 2020                                              -0.40
# May 2020                                               0.19
#
#           Administrative and support activities (N)_Exp  \
# Date
# Jan 2020                                           0.16
# Feb 2020                                          -0.03
# Mar 2020                                          -0.17
# Apr 2020                                          -0.17
# May 2020                                          -0.02
#
#           Public administration and defence (O)_Exp  Education (P)_Exp  \
# Date
# Jan 2020                                        NaN               0.03
# Feb 2020                                        NaN              -0.10
# Mar 2020                                        NaN              -0.43
# Apr 2020                                        NaN              -0.10
# May 2020                                        NaN              -0.14
#
#           Human health and social work (Q)_Exp  \
# Date
# Jan 2020                                  0.05
# Feb 2020                                  0.00
# Mar 2020                                  0.02
# Apr 2020                                  0.02
# May 2020                                 -0.09
#
#           Arts, entertainmant and recreation (R)_Exp  \
# Date
# Jan 2020                                       -0.07
# Feb 2020                                       -0.20
# Mar 2020                                       -0.16
# Apr 2020                                       -0.29
# May 2020                                        0.08
#
#           Other service activities (S)_Exp
# Date
# Jan 2020                             -0.10
# Feb 2020                              0.13
# Mar 2020                             -0.37
# Apr 2020                             -0.27
# May 2020                              0.04
#
# [5 rows x 21 columns]

# %%
#Before cleaning
vat_flash_newreporters.head()
# Out:
#           New VAT reporters, seasonally adjusted   Unnamed: 1  \
# 0             This worksheet contains one table.          NaN
# 1                     [x] = Data are unavailable          NaN
# 2  [c] = Data have been supressed for disclosure          NaN
# 3                 Office for National Statistics          NaN
# 4                                           Date  Total (A-T)
#
#          Unnamed: 2      Unnamed: 3                             Unnamed: 4  \
# 0               NaN             NaN                                    NaN
# 1               NaN             NaN                                    NaN
# 2               NaN             NaN                                    NaN
# 3               NaN             NaN                                    NaN
# 4  Production (B-E)  Services (G-T)  Agriculture, forestry and fishing (A)
#
#                  Unnamed: 5         Unnamed: 6  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4  Mining and quarrying (B)  Manufacturing (C)
#
#                             Unnamed: 7                       Unnamed: 8  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4  Electricity, gas, steam and air (D)  Water supply, sewerage, etc (E)
#
#          Unnamed: 9  ...                        Unnamed: 13  \
# 0               NaN  ...                                NaN
# 1               NaN  ...                                NaN
# 2               NaN  ...                                NaN
# 3               NaN  ...                                NaN
# 4  Construction (F)  ...  Information and communication (J)
#
#                               Unnamed: 14                 Unnamed: 15  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4  Financial and insurance activities (K)  Real estate activities (L)
#
#                                          Unnamed: 16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Professional, scientific and technical activit...
#
#                                  Unnamed: 17  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  Administrative and support activities (N)
#
#                              Unnamed: 18    Unnamed: 19  \
# 0                                    NaN            NaN
# 1                                    NaN            NaN
# 2                                    NaN            NaN
# 3                                    NaN            NaN
# 4  Public administration and defence (O)  Education (P)
#
#                         Unnamed: 20                             Unnamed: 21  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4  Human health and social work (Q)  Arts, entertainmant and recreation (R)
#
#                     Unnamed: 22
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  Other service activities (S)
#
# [5 rows x 23 columns]

# %%
#Setting required variables
vfn_header=4
vfn_droprows = [0,1,2,3,4]
vfn_dropcols = ['Total (A-T)']

#class instance
dataset_cleaning = clean(vat_flash_newreporters,setheader=True,header_int=vfn_header,droprows=True,rows_to_drop=vfn_droprows,
                         drop_cols=True,columns_to_drop=vfn_dropcols,converttonan=True,rename_cols=True,to_append='Newreporters')
vat_flash_newreporters = dataset_cleaning.final_clean()

#After cleaning
vat_flash_newreporters.head()
# Out:
#           Production (B-E)_Newreporters  Services (G-T)_Newreporters  \
# Date
# Jan 2020                         1100.0                      15430.0
# Feb 2020                         1010.0                      16380.0
# Mar 2020                          910.0                      16630.0
# Apr 2020                          740.0                      11330.0
# May 2020                          750.0                      12060.0
#
#           Agriculture, forestry and fishing (A)_Newreporters  \
# Date
# Jan 2020                                              280.0
# Feb 2020                                              260.0
# Mar 2020                                              270.0
# Apr 2020                                              230.0
# May 2020                                              250.0
#
#           Mining and quarrying (B)_Newreporters  \
# Date
# Jan 2020                                    NaN
# Feb 2020                                    NaN
# Mar 2020                                    NaN
# Apr 2020                                    NaN
# May 2020                                    NaN
#
#           Manufacturing (C)_Newreporters  \
# Date
# Jan 2020                           970.0
# Feb 2020                           840.0
# Mar 2020                           810.0
# Apr 2020                           610.0
# May 2020                           630.0
#
#           Electricity, gas, steam and air (D)_Newreporters  \
# Date
# Jan 2020                                               NaN
# Feb 2020                                               NaN
# Mar 2020                                               NaN
# Apr 2020                                               NaN
# May 2020                                               NaN
#
#           Water supply, sewerage, etc (E)_Newreporters  \
# Date
# Jan 2020                                           NaN
# Feb 2020                                           NaN
# Mar 2020                                           NaN
# Apr 2020                                           NaN
# May 2020                                           NaN
#
#           Construction (F)_Newreporters  \
# Date
# Jan 2020                         2790.0
# Feb 2020                         3020.0
# Mar 2020                         2850.0
# Apr 2020                         2200.0
# May 2020                         2310.0
#
#           Wholesale and retail; repair of motor vehicles (G)_Newreporters  \
# Date
# Jan 2020                                             4420.0
# Feb 2020                                             4260.0
# Mar 2020                                             4220.0
# Apr 2020                                             3260.0
# May 2020                                             3410.0
#
#           Transport and storage (H)_Newreporters  ...  \
# Date                                              ...
# Jan 2020                                  1540.0  ...
# Feb 2020                                  2210.0  ...
# Mar 2020                                  2890.0  ...
# Apr 2020                                  1330.0  ...
# May 2020                                  1550.0  ...
#
#           Information and communication (J)_Newreporters  \
# Date
# Jan 2020                                          1780.0
# Feb 2020                                          1760.0
# Mar 2020                                          1590.0
# Apr 2020                                          1260.0
# May 2020                                          1250.0
#
#           Financial and insurance activities (K)_Newreporters  \
# Date
# Jan 2020                                              190.0
# Feb 2020                                              190.0
# Mar 2020                                              140.0
# Apr 2020                                              170.0
# May 2020                                              170.0
#
#           Real estate activities (L)_Newreporters  \
# Date
# Jan 2020                                    590.0
# Feb 2020                                    610.0
# Mar 2020                                    520.0
# Apr 2020                                    510.0
# May 2020                                    490.0
#
#           Professional, scientific and technical activities (M)_Newreporters  \
# Date
# Jan 2020                                             3000.0
# Feb 2020                                             2940.0
# Mar 2020                                             2810.0
# Apr 2020                                             2230.0
# May 2020                                             2350.0
#
#           Administrative and support activities (N)_Newreporters  \
# Date
# Jan 2020                                             1310.0
# Feb 2020                                             1360.0
# Mar 2020                                             1310.0
# Apr 2020                                              910.0
# May 2020                                              990.0
#
#           Public administration and defence (O)_Newreporters  \
# Date
# Jan 2020                                                NaN
# Feb 2020                                                NaN
# Mar 2020                                                NaN
# Apr 2020                                                NaN
# May 2020                                                NaN
#
#           Education (P)_Newreporters  \
# Date
# Jan 2020                       220.0
# Feb 2020                       180.0
# Mar 2020                       160.0
# Apr 2020                       160.0
# May 2020                       150.0
#
#           Human health and social work (Q)_Newreporters  \
# Date
# Jan 2020                                            NaN
# Feb 2020                                            NaN
# Mar 2020                                            NaN
# Apr 2020                                            NaN
# May 2020                                            NaN
#
#           Arts, entertainmant and recreation (R)_Newreporters  \
# Date
# Jan 2020                                              430.0
# Feb 2020                                              470.0
# Mar 2020                                              480.0
# Apr 2020                                              420.0
# May 2020                                              400.0
#
#           Other service activities (S)_Newreporters
# Date
# Jan 2020                                      290.0
# Feb 2020                                      320.0
# Mar 2020                                      290.0
# Apr 2020                                      270.0
# May 2020                                      260.0
#
# [5 rows x 21 columns]

# %%
#Before cleaning
vat_flash_records.head()
# Out:
#   Number of reporters by record type, seasonally adjusted       Unnamed: 1  \
# 0                 This worksheet contains one table.                   NaN
# 1                         [x] = Data are unavailable                   NaN
# 2      [c] = Data have been supressed for disclosure                   NaN
# 3                     Office for National Statistics                   NaN
# 4                                               Date       Total - Tax due
#
#                 Unnamed: 2                Unnamed: 3  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4  Total - Repayment claim  Total - Re-input tax due
#
#                          Unnamed: 4            Unnamed: 5  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4  Total - Re-input repayment claim  Production - Tax due
#
#                      Unnamed: 6                     Unnamed: 7  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4  Production - Repayment claim  Production - Re-input tax due
#
#                               Unnamed: 8          Unnamed: 9  ...  \
# 0                                    NaN                 NaN  ...
# 1                                    NaN                 NaN  ...
# 2                                    NaN                 NaN  ...
# 3                                    NaN                 NaN  ...
# 4  Production - Re-input repayment claim  Services - Tax due  ...
#
#             Unnamed: 79                   Unnamed: 80  Unnamed: 81  \
# 0                   NaN                           NaN          NaN
# 1                   NaN                           NaN          NaN
# 2                   NaN                           NaN          NaN
# 3                   NaN                           NaN          NaN
# 4  Q - Re-input tax due  Q - Re-input repayment claim  R - Tax due
#
#            Unnamed: 82           Unnamed: 83                   Unnamed: 84  \
# 0                  NaN                   NaN                           NaN
# 1                  NaN                   NaN                           NaN
# 2                  NaN                   NaN                           NaN
# 3                  NaN                   NaN                           NaN
# 4  R - Repayment claim  R - Re-input tax due  R - Re-input repayment claim
#
#    Unnamed: 85          Unnamed: 86           Unnamed: 87  \
# 0          NaN                  NaN                   NaN
# 1          NaN                  NaN                   NaN
# 2          NaN                  NaN                   NaN
# 3          NaN                  NaN                   NaN
# 4  S - Tax due  S - Repayment claim  S - Re-input tax due
#
#                     Unnamed: 88
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4  S - Re-input repayment claim
#
# [5 rows x 89 columns]

# %%
#Setting required variables
vfr_header=4
vfr_droprows = [0,1,2,3,4]
vfr_dropcols = ['Total - Tax due','Total - Repayment claim','Total - Re-input tax due','Total - Re-input repayment claim']

#class instance
dataset_cleaning = clean(vat_flash_records,setheader=True,header_int=vfr_header,droprows=True,rows_to_drop=vfr_droprows,
                         drop_cols=True,columns_to_drop=vfr_dropcols,converttonan=True)
vat_flash_records = dataset_cleaning.final_clean()

#After cleaning
vat_flash_records.head()
# Out:
#           Production - Tax due  Production - Repayment claim  \
# Date
# Jan 2020               33050.0                       13560.0
# Feb 2020               34090.0                       13770.0
# Mar 2020               31330.0                       13490.0
# Apr 2020               29970.0                       13110.0
# May 2020               32320.0                       12400.0
#
#           Production - Re-input tax due  \
# Date
# Jan 2020                            NaN
# Feb 2020                            NaN
# Mar 2020                            NaN
# Apr 2020                            NaN
# May 2020                            NaN
#
#           Production - Re-input repayment claim  Services - Tax due  \
# Date
# Jan 2020                                    NaN            393520.0
# Feb 2020                                    NaN            402550.0
# Mar 2020                                    NaN            356320.0
# Apr 2020                                    NaN            354250.0
# May 2020                                    NaN            365400.0
#
#           Services - Repayment claim  Services - Re-input tax due  \
# Date
# Jan 2020                     98320.0                        690.0
# Feb 2020                     99830.0                        650.0
# Mar 2020                     95310.0                        520.0
# Apr 2020                     95360.0                        470.0
# May 2020                     91240.0                        540.0
#
#           Services - Re-input repayment claim  A - Tax due  \
# Date
# Jan 2020                                  NaN       8920.0
# Feb 2020                                  NaN       9120.0
# Mar 2020                                  NaN       8260.0
# Apr 2020                                  NaN       8430.0
# May 2020                                  NaN       8410.0
#
#           A - Repayment claim  ...  Q - Re-input tax due  \
# Date                           ...
# Jan 2020              48020.0  ...                   NaN
# Feb 2020              48210.0  ...                   NaN
# Mar 2020              46040.0  ...                   NaN
# Apr 2020              47070.0  ...                   NaN
# May 2020              45720.0  ...                   NaN
#
#           Q - Re-input repayment claim  R - Tax due  R - Repayment claim  \
# Date
# Jan 2020                           NaN      11870.0               5340.0
# Feb 2020                           NaN      12250.0               5340.0
# Mar 2020                           NaN      11250.0               5260.0
# Apr 2020                           NaN      11530.0               5220.0
# May 2020                           NaN      11370.0               5400.0
#
#           R - Re-input tax due  R - Re-input repayment claim  S - Tax due  \
# Date
# Jan 2020                   NaN                           NaN      13280.0
# Feb 2020                   NaN                           NaN      13480.0
# Mar 2020                   NaN                           NaN      12200.0
# Apr 2020                   NaN                           NaN      12710.0
# May 2020                   NaN                           NaN      12670.0
#
#           S - Repayment claim  S - Re-input tax due  \
# Date
# Jan 2020               2370.0                   NaN
# Feb 2020               2330.0                   NaN
# Mar 2020               2310.0                   NaN
# Apr 2020               2170.0                   NaN
# May 2020               2250.0                   NaN
#
#           S - Re-input repayment claim
# Date
# Jan 2020                           NaN
# Feb 2020                           NaN
# Mar 2020                           NaN
# Apr 2020                           NaN
# May 2020                           NaN
#
# [5 rows x 84 columns]

# %%
#Before cleaning
gdp_data.head()
# Out:
#   Figure 1: UK Gross domestic product (GDP) is estimated to have fallen by 0.5% in December 2022  \
# 0   Monthly index, January 2007 to December 2022, UK
# 1                                                NaN
# 2                                              Notes
# 3                                               Unit
# 4                                                NaN
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Office for National Statistics – GDP monthly e...
# 4                                                NaN

# %%
#GDP cleaning

#Setting required variables
gdp_header=5
gdp_droprows = [0,1,2,3,4,5]

#class instance
dataset_cleaning = clean(gdp_data,setheader= True,header_int=gdp_header,droprows=True,rows_to_drop=gdp_droprows,to_datetime=True)
gdp_data = dataset_cleaning.final_clean()

#After cleaning
gdp_data.head()
# Out:
#           Monthly GDP
# Date
# Jan 2020        100.7
# Feb 2020        100.2
# Mar 2020         93.1
# Apr 2020         73.7
# May 2020         76.0

# %% [markdown]
# # Merging Datasets

# %%
#Datasets list including the GDP data
list_datasets=[gdp_data,company_incorporations_incorp,company_incorporations_vol,company_incorporations_comp,hr1_redundancies,online_job_adverts_category,online_job_adverts_region,uk_small_businesses_jobs,uk_small_businesses_sales,vat_flash_turnover,vat_flash_exp,vat_flash_newreporters,vat_flash_records]

# %%
#Merge datasets 
business_insights = pd.concat(list_datasets ,join = 'outer',axis=1)

# %%
business_insights.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, Jan 2020 to Dec 2022
# Data columns (total 216 columns):
#  #    Column                                                              Non-Null Count  Dtype
# ---   ------                                                              --------------  -----
#  0    Monthly GDP                                                         36 non-null     float64
#  1    Weekly_Incorporations                                               36 non-null     float64
#  2    Weekly_Voluntary_Dissolutions                                       36 non-null     float64
#  3    Weekly_Compulsory_Dissolutions                                      36 non-null     float64
#  4    Potential redundancies                                              36 non-null     float64
#  5    Employers proposing redundancies                                    36 non-null     float64
#  6    Accounting / Finance_category                                       36 non-null     float64
#  7    Admin / clerical / secretarial_category                             36 non-null     float64
#  8    Catering and hospitality_category                                   36 non-null     float64
#  9    Charity / voluntary_category                                        36 non-null     float64
#  10   Construction / trades_category                                      36 non-null     float64
#  11   Creative / design / arts & media_category                           36 non-null     float64
#  12   Customer service / support_category                                 36 non-null     float64
#  13   Domestic help_category                                              36 non-null     float64
#  14   Education_category                                                  36 non-null     float64
#  15   Energy / oil & gas_category                                         36 non-null     float64
#  16   Engineering_category                                                36 non-null     float64
#  17   Facilities / maintenance_category                                   36 non-null     float64
#  18   Graduate_category                                                   36 non-null     float64
#  19   HR & recruitment_category                                           36 non-null     float64
#  20   IT / Computing / Software_category                                  36 non-null     float64
#  21   Legal_category                                                      36 non-null     float64
#  22   Management / exec / consulting_category                             36 non-null     float64
#  23   Manufacturing_category                                              36 non-null     float64
#  24   Marketing / advertising / PR_category                               36 non-null     float64
#  25   Other / general_category                                            36 non-null     float64
#  26   Part-time / weekend_category                                        36 non-null     float64
#  27   Property_category                                                   36 non-null     float64
#  28   Wholesale and retail_category                                       36 non-null     float64
#  29   Sales_category                                                      36 non-null     float64
#  30   Scientific / QA_category                                            36 non-null     float64
#  31   Transport / logistics / warehouse_category                          36 non-null     float64
#  32   Travel / tourism_category                                           36 non-null     float64
#  33   Unknown_category                                                    36 non-null     float64
#  34   Healthcare and Social care_category                                 36 non-null     float64
#  35   East Midlands_region                                                36 non-null     float64
#  36   East of England_region                                              36 non-null     float64
#  37   London_region                                                       36 non-null     float64
#  38   North East_region                                                   36 non-null     float64
#  39   North West_region                                                   36 non-null     float64
#  40   Northern Ireland_region                                             36 non-null     float64
#  41   Scotland_region                                                     36 non-null     float64
#  42   South East_region                                                   36 non-null     float64
#  43   South West_region                                                   36 non-null     float64
#  44   Unknown_region                                                      36 non-null     float64
#  45   Wales_region                                                        36 non-null     float64
#  46   West Midlands_region                                                36 non-null     float64
#  47   Yorkshire and The Humber_region                                     36 non-null     float64
#  48   England_region                                                      36 non-null     float64
#  49   Manufacturing_Jobs                                                  36 non-null     float64
#  50   Construction_Jobs                                                   36 non-null     float64
#  51   Retail Trade_Jobs                                                   36 non-null     float64
#  52   Accommodation and Food Services_Jobs                                36 non-null     float64
#  53   Information Media and Telecommunications_Jobs                       36 non-null     float64
#  54   Rental, Hiring and Real Estate Services_Jobs                        36 non-null     float64
#  55   Professional, Scientific and Technical Services_Jobs                36 non-null     float64
#  56   Administrative and Support Services_Jobs                            36 non-null     float64
#  57   Other Services_Jobs                                                 36 non-null     float64
#  58   Health Care and Social Assistance_Jobs                              36 non-null     float64
#  59   Manufacturing_Sales                                                 36 non-null     float64
#  60   Construction_Sales                                                  36 non-null     float64
#  61   Retail Trade_Sales                                                  36 non-null     float64
#  62   Accommodation and Food Services_Sales                               36 non-null     float64
#  63   Information Media and Telecommunications_Sales                      36 non-null     float64
#  64   Rental, Hiring and Real Estate Services_Sales                       36 non-null     float64
#  65   Professional, Scientific and Technical Services_Sales               36 non-null     float64
#  66   Administrative and Support Services_Sales                           36 non-null     float64
#  67   Other Services_Sales                                                36 non-null     float64
#  68   Health Care and Social Assistance_Sales                             36 non-null     float64
#  69   Production (B-E)_Turnover                                           36 non-null     float64
#  70   Services (G-T)_Turnover                                             36 non-null     float64
#  71   Agriculture, forestry and fishing (A)_Turnover                      36 non-null     float64
#  72   Mining and quarrying (B)_Turnover                                   0 non-null      float64
#  73   Manufacturing (C)_Turnover                                          36 non-null     float64
#  74   Electricity, gas, steam and air (D)_Turnover                        0 non-null      float64
#  75   Water supply, sewerage, etc (E)_Turnover                            0 non-null      float64
#  76   Construction (F)_Turnover                                           36 non-null     float64
#  77   Wholesale and retail; repair of motor vehicles (G)_Turnover         36 non-null     float64
#  78   Transport and storage (H)_Turnover                                  36 non-null     float64
#  79   Accommodation and food services (I)_Turnover                        36 non-null     float64
#  80   Information and communication (J)_Turnover                          36 non-null     float64
#  81   Financial and insurance activities (K)_Turnover                     0 non-null      float64
#  82   Real estate activities (L)_Turnover                                 36 non-null     float64
#  83   Professional, scientific and technical activities (M)_Turnover      36 non-null     float64
#  84   Administrative and support activities (N)_Turnover                  36 non-null     float64
#  85   Public administration and defence (O)_Turnover                      0 non-null      float64
#  86   Education (P)_Turnover                                              36 non-null     float64
#  87   Human health and social work (Q)_Turnover                           36 non-null     float64
#  88   Arts, entertainmant and recreation (R)_Turnover                     36 non-null     float64
#  89   Other service activities (S)_Turnover                               36 non-null     float64
#  90   Production (B-E)_Exp                                                36 non-null     float64
#  91   Services (G-T)_Exp                                                  36 non-null     float64
#  92   Agriculture, forestry and fishing (A)_Exp                           36 non-null     float64
#  93   Mining and quarrying (B)_Exp                                        0 non-null      float64
#  94   Manufacturing (C)_Exp                                               36 non-null     float64
#  95   Electricity, gas, steam and air (D)_Exp                             36 non-null     float64
#  96   Water supply, sewerage, etc (E)_Exp                                 0 non-null      float64
#  97   Construction (F)_Exp                                                36 non-null     float64
#  98   Wholesale and retail; repair of motor vehicles (G)_Exp              36 non-null     float64
#  99   Transport and storage (H)_Exp                                       36 non-null     float64
#  100  Accommodation and food services (I)_Exp                             36 non-null     float64
#  101  Information and communication (J)_Exp                               36 non-null     float64
#  102  Financial and insurance activities (K)_Exp                          0 non-null      float64
#  103  Real estate activities (L)_Exp                                      36 non-null     float64
#  104  Professional, scientific and technical activities (M)_Exp           36 non-null     float64
#  105  Administrative and support activities (N)_Exp                       36 non-null     float64
#  106  Public administration and defence (O)_Exp                           0 non-null      float64
#  107  Education (P)_Exp                                                   36 non-null     float64
#  108  Human health and social work (Q)_Exp                                36 non-null     float64
#  109  Arts, entertainmant and recreation (R)_Exp                          36 non-null     float64
#  110  Other service activities (S)_Exp                                    36 non-null     float64
#  111  Production (B-E)_Newreporters                                       36 non-null     float64
#  112  Services (G-T)_Newreporters                                         36 non-null     float64
#  113  Agriculture, forestry and fishing (A)_Newreporters                  36 non-null     float64
#  114  Mining and quarrying (B)_Newreporters                               0 non-null      float64
#  115  Manufacturing (C)_Newreporters                                      36 non-null     float64
#  116  Electricity, gas, steam and air (D)_Newreporters                    0 non-null      float64
#  117  Water supply, sewerage, etc (E)_Newreporters                        0 non-null      float64
#  118  Construction (F)_Newreporters                                       36 non-null     float64
#  119  Wholesale and retail; repair of motor vehicles (G)_Newreporters     36 non-null     float64
#  120  Transport and storage (H)_Newreporters                              36 non-null     float64
#  121  Accommodation and food services (I)_Newreporters                    36 non-null     float64
#  122  Information and communication (J)_Newreporters                      36 non-null     float64
#  123  Financial and insurance activities (K)_Newreporters                 36 non-null     float64
#  124  Real estate activities (L)_Newreporters                             36 non-null     float64
#  125  Professional, scientific and technical activities (M)_Newreporters  36 non-null     float64
#  126  Administrative and support activities (N)_Newreporters              36 non-null     float64
#  127  Public administration and defence (O)_Newreporters                  0 non-null      float64
#  128  Education (P)_Newreporters                                          36 non-null     float64
#  129  Human health and social work (Q)_Newreporters                       0 non-null      float64
#  130  Arts, entertainmant and recreation (R)_Newreporters                 36 non-null     float64
#  131  Other service activities (S)_Newreporters                           36 non-null     float64
#  132  Production - Tax due                                                36 non-null     float64
#  133  Production - Repayment claim                                        36 non-null     float64
#  134  Production - Re-input tax due                                       0 non-null      float64
#  135  Production - Re-input repayment claim                               0 non-null      float64
#  136  Services - Tax due                                                  36 non-null     float64
#  137  Services - Repayment claim                                          36 non-null     float64
#  138  Services - Re-input tax due                                         36 non-null     float64
#  139  Services - Re-input repayment claim                                 0 non-null      float64
#  140  A - Tax due                                                         36 non-null     float64
#  141  A - Repayment claim                                                 36 non-null     float64
#  142  A - Re-input tax due                                                0 non-null      float64
#  143  A - Re-input repayment claim                                        0 non-null      float64
#  144  B - Tax due                                                         36 non-null     float64
#  145  B - Repayment claim                                                 36 non-null     float64
#  146  B - Re-input tax due                                                0 non-null      float64
#  147  B - Re-input repayment claim                                        0 non-null      float64
#  148  C - Tax due                                                         36 non-null     float64
#  149  C - Repayment claim                                                 36 non-null     float64
#  150  C - Re-input tax due                                                0 non-null      float64
#  151  C - Re-input repayment claim                                        0 non-null      float64
#  152  D - Tax due                                                         36 non-null     float64
#  153  D - Repayment claim                                                 36 non-null     float64
#  154  D - Re-input tax due                                                0 non-null      float64
#  155  D - Re-input repayment claim                                        0 non-null      float64
#  156  E - Tax due                                                         36 non-null     float64
#  157  E - Repayment claim                                                 36 non-null     float64
#  158  E - Re-input tax due                                                0 non-null      float64
#  159  E - Re-input repayment claim                                        0 non-null      float64
#  160  F - Tax due                                                         36 non-null     float64
#  161  F - Repayment claim                                                 36 non-null     float64
#  162  F - Re-input tax due                                                0 non-null      float64
#  163  F - Re-input repayment claim                                        0 non-null      float64
#  164  G - Tax due                                                         36 non-null     float64
#  165  G - Repayment claim                                                 36 non-null     float64
#  166  G - Re-input tax due                                                36 non-null     float64
#  167  G - Re-input repayment claim                                        0 non-null      float64
#  168  H - Tax due                                                         36 non-null     float64
#  169  H - Repayment claim                                                 36 non-null     float64
#  170  H - Re-input tax due                                                0 non-null      float64
#  171  H - Re-input repayment claim                                        0 non-null      float64
#  172  I - Tax due                                                         36 non-null     float64
#  173  I - Repayment claim                                                 36 non-null     float64
#  174  I - Re-input tax due                                                0 non-null      float64
#  175  I - Re-input repayment claim                                        0 non-null      float64
#  176  J - Tax due                                                         36 non-null     float64
#  177  J - Repayment claim                                                 36 non-null     float64
#  178  J - Re-input tax due                                                0 non-null      float64
#  179  J - Re-input repayment claim                                        0 non-null      float64
#  180  K - Tax due                                                         36 non-null     float64
#  181  K - Repayment claim                                                 36 non-null     float64
#  182  K - Re-input tax due                                                0 non-null      float64
#  183  K - Re-input repayment claim                                        0 non-null      float64
#  184  L - Tax due                                                         36 non-null     float64
#  185  L - Repayment claim                                                 36 non-null     float64
#  186  L - Re-input tax due                                                0 non-null      float64
#  187  L - Re-input repayment claim                                        0 non-null      float64
#  188  M - Tax due                                                         36 non-null     float64
#  189  M - Repayment claim                                                 36 non-null     float64
#  190  M - Re-input tax due                                                0 non-null      float64
#  191  M - Re-input repayment claim                                        0 non-null      float64
#  192  N - Tax due                                                         36 non-null     float64
#  193  N - Repayment claim                                                 36 non-null     float64
#  194  N - Re-input tax due                                                0 non-null      float64
#  195  N - Re-input repayment claim                                        0 non-null      float64
#  196  O - Tax due                                                         0 non-null      float64
#  197  O - Repayment claim                                                 0 non-null      float64
#  198  O - Re-input tax due                                                0 non-null      float64
#  199  O - Re-input repayment claim                                        0 non-null      float64
#  200  P - Tax due                                                         36 non-null     float64
#  201  P - Repayment claim                                                 36 non-null     float64
#  202  P - Re-input tax due                                                0 non-null      float64
#  203  P - Re-input repayment claim                                        0 non-null      float64
#  204  Q - Tax due                                                         36 non-null     float64
#  205  Q - Repayment claim                                                 36 non-null     float64
#  206  Q - Re-input tax due                                                0 non-null      float64
#  207  Q - Re-input repayment claim                                        0 non-null      float64
#  208  R - Tax due                                                         36 non-null     float64
#  209  R - Repayment claim                                                 36 non-null     float64
#  210  R - Re-input tax due                                                0 non-null      float64
#  211  R - Re-input repayment claim                                        0 non-null      float64
#  212  S - Tax due                                                         36 non-null     float64
#  213  S - Repayment claim                                                 36 non-null     float64
#  214  S - Re-input tax due                                                0 non-null      float64
#  215  S - Re-input repayment claim                                        0 non-null      float64
# dtypes: float64(216)
# memory usage: 61.0+ KB

# %%
business_insights.to_csv(r'Merged_Business_Insights.csv')

# %% [markdown]
# # Missing Values

# %%
#Define target variable and predictor variable
y = business_insights.loc['Jan 2020':'Dec 2022','Monthly GDP']
X = business_insights.drop(columns='Monthly GDP')
X = X.loc['Jan 2020':'Dec 2022',:]

# %%
#Create function for imputation of missing values usin KNN
def missingvalues(X):
    # check for columns that have all null values and convert to a list
    empty_train_columns = X.columns[X.isnull().all()].tolist()
    #drop those columns from the dataset
    X = X.drop(empty_train_columns, axis=1)
    #Impute missing values
    KNN_imputer = KNNImputer(n_neighbors=3)
    #Create new dataset
    X_new = pd.DataFrame(data=KNN_imputer.fit_transform(X), columns=X.columns)
    return X_new

X_new = missingvalues(X)

# %%
#create corr mask for upper triangle
corr_X = X_new.corr().abs()
mask = np.triu(np.ones_like(corr_X, dtype=bool))
tri_X = corr_X.mask(mask)
tri_X.head()
# Out:
#                                   Weekly_Incorporations  \
# Weekly_Incorporations                               NaN
# Weekly_Voluntary_Dissolutions                  0.260258
# Weekly_Compulsory_Dissolutions                 0.125277
# Potential redundancies                         0.335835
# Employers proposing redundancies               0.436100
#
#                                   Weekly_Voluntary_Dissolutions  \
# Weekly_Incorporations                                       NaN
# Weekly_Voluntary_Dissolutions                               NaN
# Weekly_Compulsory_Dissolutions                         0.428231
# Potential redundancies                                 0.546319
# Employers proposing redundancies                       0.512191
#
#                                   Weekly_Compulsory_Dissolutions  \
# Weekly_Incorporations                                        NaN
# Weekly_Voluntary_Dissolutions                                NaN
# Weekly_Compulsory_Dissolutions                               NaN
# Potential redundancies                                  0.627100
# Employers proposing redundancies                        0.641606
#
#                                   Potential redundancies  \
# Weekly_Incorporations                                NaN
# Weekly_Voluntary_Dissolutions                        NaN
# Weekly_Compulsory_Dissolutions                       NaN
# Potential redundancies                               NaN
# Employers proposing redundancies                0.975173
#
#                                   Employers proposing redundancies  \
# Weekly_Incorporations                                          NaN
# Weekly_Voluntary_Dissolutions                                  NaN
# Weekly_Compulsory_Dissolutions                                 NaN
# Potential redundancies                                         NaN
# Employers proposing redundancies                               NaN
#
#                                   Accounting / Finance_category  \
# Weekly_Incorporations                                       NaN
# Weekly_Voluntary_Dissolutions                               NaN
# Weekly_Compulsory_Dissolutions                              NaN
# Potential redundancies                                      NaN
# Employers proposing redundancies                            NaN
#
#                                   Admin / clerical / secretarial_category  \
# Weekly_Incorporations                                                 NaN
# Weekly_Voluntary_Dissolutions                                         NaN
# Weekly_Compulsory_Dissolutions                                        NaN
# Potential redundancies                                                NaN
# Employers proposing redundancies                                      NaN
#
#                                   Catering and hospitality_category  \
# Weekly_Incorporations                                           NaN
# Weekly_Voluntary_Dissolutions                                   NaN
# Weekly_Compulsory_Dissolutions                                  NaN
# Potential redundancies                                          NaN
# Employers proposing redundancies                                NaN
#
#                                   Charity / voluntary_category  \
# Weekly_Incorporations                                      NaN
# Weekly_Voluntary_Dissolutions                              NaN
# Weekly_Compulsory_Dissolutions                             NaN
# Potential redundancies                                     NaN
# Employers proposing redundancies                           NaN
#
#                                   Construction / trades_category  ...  \
# Weekly_Incorporations                                        NaN  ...
# Weekly_Voluntary_Dissolutions                                NaN  ...
# Weekly_Compulsory_Dissolutions                               NaN  ...
# Potential redundancies                                       NaN  ...
# Employers proposing redundancies                             NaN  ...
#
#                                   N - Tax due  N - Repayment claim  \
# Weekly_Incorporations                     NaN                  NaN
# Weekly_Voluntary_Dissolutions             NaN                  NaN
# Weekly_Compulsory_Dissolutions            NaN                  NaN
# Potential redundancies                    NaN                  NaN
# Employers proposing redundancies          NaN                  NaN
#
#                                   P - Tax due  P - Repayment claim  \
# Weekly_Incorporations                     NaN                  NaN
# Weekly_Voluntary_Dissolutions             NaN                  NaN
# Weekly_Compulsory_Dissolutions            NaN                  NaN
# Potential redundancies                    NaN                  NaN
# Employers proposing redundancies          NaN                  NaN
#
#                                   Q - Tax due  Q - Repayment claim  \
# Weekly_Incorporations                     NaN                  NaN
# Weekly_Voluntary_Dissolutions             NaN                  NaN
# Weekly_Compulsory_Dissolutions            NaN                  NaN
# Potential redundancies                    NaN                  NaN
# Employers proposing redundancies          NaN                  NaN
#
#                                   R - Tax due  R - Repayment claim  \
# Weekly_Incorporations                     NaN                  NaN
# Weekly_Voluntary_Dissolutions             NaN                  NaN
# Weekly_Compulsory_Dissolutions            NaN                  NaN
# Potential redundancies                    NaN                  NaN
# Employers proposing redundancies          NaN                  NaN
#
#                                   S - Tax due  S - Repayment claim
# Weekly_Incorporations                     NaN                  NaN
# Weekly_Voluntary_Dissolutions             NaN                  NaN
# Weekly_Compulsory_Dissolutions            NaN                  NaN
# Potential redundancies                    NaN                  NaN
# Employers proposing redundancies          NaN                  NaN
#
# [5 rows x 159 columns]

# %%
#Find columns to be dropped
to_drop = [c for c in tri_X.columns if any(tri_X[c] > 0.8)]
print(to_drop)
# Out:
# ['Weekly_Voluntary_Dissolutions', 'Potential redundancies', 'Accounting / Finance_category', 'Admin / clerical / secretarial_category', 'Catering and hospitality_category', 'Charity / voluntary_category', 'Construction / trades_category', 'Creative / design / arts & media_category', 'Customer service / support_category', 'Domestic help_category', 'Education_category', 'Energy / oil & gas_category', 'Engineering_category', 'Facilities / maintenance_category', 'Graduate_category', 'HR & recruitment_category', 'IT / Computing / Software_category', 'Legal_category', 'Management / exec / consulting_category', 'Manufacturing_category', 'Marketing / advertising / PR_category', 'Other / general_category', 'Part-time / weekend_category', 'Property_category', 'Wholesale and retail_category', 'Sales_category', 'Scientific / QA_category', 'Transport / logistics / warehouse_category', 'Travel / tourism_category', 'East Midlands_region', 'East of England_region', 'London_region', 'North East_region', 'North West_region', 'Northern Ireland_region', 'Scotland_region', 'South East_region', 'South West_region', 'Unknown_region', 'Wales_region', 'West Midlands_region', 'Yorkshire and The Humber_region', 'Manufacturing_Jobs', 'Construction_Jobs', 'Retail Trade_Jobs', 'Accommodation and Food Services_Jobs', 'Information Media and Telecommunications_Jobs', 'Rental, Hiring and Real Estate Services_Jobs', 'Professional, Scientific and Technical Services_Jobs', 'Administrative and Support Services_Jobs', 'Other Services_Jobs', 'Health Care and Social Assistance_Jobs', 'Manufacturing_Sales', 'Construction_Sales', 'Retail Trade_Sales', 'Accommodation and Food Services_Sales', 'Information Media and Telecommunications_Sales', 'Rental, Hiring and Real Estate Services_Sales', 'Professional, Scientific and Technical Services_Sales', 'Administrative and Support Services_Sales', 'Other Services_Sales', 'Production (B-E)_Turnover', 'Services (G-T)_Turnover', 'Construction (F)_Turnover', 'Wholesale and retail; repair of motor vehicles (G)_Turnover', 'Transport and storage (H)_Turnover', 'Production (B-E)_Exp', 'Services (G-T)_Exp', 'Manufacturing (C)_Exp', 'Production (B-E)_Newreporters', 'Services (G-T)_Newreporters', 'Manufacturing (C)_Newreporters', 'Construction (F)_Newreporters', 'Accommodation and food services (I)_Newreporters', 'Information and communication (J)_Newreporters', 'Real estate activities (L)_Newreporters', 'Production - Repayment claim', 'Services - Tax due', 'Services - Repayment claim', 'Services - Re-input tax due', 'A - Tax due', 'B - Tax due', 'B - Repayment claim', 'C - Repayment claim', 'D - Repayment claim', 'E - Repayment claim', 'F - Tax due', 'F - Repayment claim', 'G - Repayment claim', 'H - Repayment claim', 'I - Tax due', 'I - Repayment claim', 'J - Tax due', 'J - Repayment claim', 'K - Tax due', 'K - Repayment claim', 'L - Repayment claim', 'M - Repayment claim', 'P - Tax due', 'P - Repayment claim', 'R - Tax due', 'R - Repayment claim', 'S - Tax due']

# %%
#Drop Columns
X_reduced = X_new.drop(columns = to_drop)
X_reduced.head()
# Out:
#    Weekly_Incorporations  Weekly_Compulsory_Dissolutions  \
# 0               12162.20                         5827.50
# 1               14276.00                         8851.00
# 2               12359.75                         7569.00
# 3                9041.25                         2925.25
# 4               12878.40                            5.50
#
#    Employers proposing redundancies  Unknown_category  \
# 0                             50.25           126.520
# 1                             73.00           100.000
# 2                             77.80           142.875
# 3                             58.50            37.775
# 4                            141.40            21.540
#
#    Healthcare and Social care_category  England_region  \
# 0                               94.860          94.620
# 1                               99.975          99.975
# 2                               96.300          92.350
# 3                               92.225          56.625
# 4                               85.660          38.240
#
#    Health Care and Social Assistance_Sales  \
# 0                                    109.6
# 1                                    109.3
# 2                                    106.4
# 3                                     95.6
# 4                                     90.8
#
#    Agriculture, forestry and fishing (A)_Turnover  Manufacturing (C)_Turnover  \
# 0                                            0.03                        0.04
# 1                                            0.00                       -0.03
# 2                                           -0.02                       -0.30
# 3                                           -0.09                       -0.28
# 4                                            0.05                        0.06
#
#    Accommodation and food services (I)_Turnover  ...  G - Tax due  \
# 0                                          0.14  ...      92410.0
# 1                                         -0.02  ...      93170.0
# 2                                         -0.59  ...      93230.0
# 3                                         -0.53  ...      83120.0
# 4                                         -0.37  ...      83290.0
#
#    G - Re-input tax due  H - Tax due  L - Tax due  M - Tax due  N - Tax due  \
# 0                 200.0      21730.0      26270.0      95080.0      33200.0
# 1                 180.0      21020.0      25650.0      96720.0      33050.0
# 2                 180.0      20810.0      23780.0      87150.0      31890.0
# 3                 140.0      17610.0      23740.0      87470.0      30200.0
# 4                 160.0      22840.0      24850.0      88670.0      31680.0
#
#    N - Repayment claim  Q - Tax due  Q - Repayment claim  S - Repayment claim
# 0               8380.0       2140.0               1520.0               2370.0
# 1               8650.0       2230.0               1530.0               2330.0
# 2               8620.0       2050.0               1470.0               2310.0
# 3               8400.0       2020.0               1560.0               2170.0
# 4               8290.0       2280.0               1540.0               2250.0
#
# [5 rows x 56 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Ensemble

# %%
#Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, random_state=19042351)

#Scale data
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
#Function for ensemble feature selection
def ensemble(X_train_std,X_test_std,y_train,y_test,num_votes):
    cv = RepeatedKFold(n_splits=10, n_repeats=10, random_state=2)
    #Find alpha
    lcv = LassoCV(max_iter=5000,random_state=19042351, selection='random')
    lcv.fit(X_train_std, y_train)
    lcv_alpha = lcv.alpha_
    
    #Fit Lasso
    lasso = Lasso(alpha=lcv_alpha,max_iter=5000,random_state=19042351, selection='random')
    lasso.fit(X_train_std, y_train)
    
    #Lasso features mask
    lasso_mask = lasso.coef_ != 0
    

    #Gradient boosting features mask
    rfe_gb = RFECV(estimator=GradientBoostingRegressor(random_state=19042351), step=3,min_features_to_select=1,cv=cv, verbose=0)
    rfe_gb.fit(X_train_std, y_train)
    gb_mask = rfe_gb.support_
    
    #Random forest features mask
    rfe_rf = RFECV(estimator=RandomForestRegressor(random_state=19042351), step=3,min_features_to_select=1,cv=cv, verbose=0)
    rfe_rf.fit(X_train_std, y_train)
    rf_mask = rfe_rf.support_
    
    #sum votes from all three models
    votes = np.sum([lasso_mask, rf_mask, gb_mask], axis=0)
    
    #Set Criteria for mask - 2 or more votes
    all_votes_mask = votes >= num_votes
    
    #New Dataset with selected features 
    X_selected = X_new.loc[:, all_votes_mask]
    
    list_scores = [lasso.score(X_test_std, y_test),rfe_gb.score(X_test_std, y_test),rfe_rf.score(X_test_std, y_test)]
    average_score = sum(list_scores)/len(list_scores)
    
    print(f'Number of columns before feature selection:{X_train_std.shape[1]}')
    print(f'Number of columns after feature selection:{X_selected.shape[1]}')
    print(f'Average accuracy score : {average_score:.1%}\n Lasso model : {lasso.score(X_test_std, y_test):.1%}\n Gradient Boosting model : {rfe_gb.score(X_test_std, y_test):.1%}\n Random Forest model : {rfe_rf.score(X_test_std, y_test):.1%}')

    
    print(X_selected.columns.values)
    return X_selected
    
X_BusinessInsights = ensemble(X_train_std,X_test_std,y_train,y_test,2)
# Out:
# Number of columns before feature selection:159
# Number of columns after feature selection:73
# Average accuracy score : 85.8%
#  Lasso model : 81.4%
#  Gradient Boosting model : 91.0%
#  Random Forest model : 84.9%
# ['Potential redundancies' 'Employers proposing redundancies'
#  'Admin / clerical / secretarial_category'
#  'Catering and hospitality_category' 'Charity / voluntary_category'
#  'Construction / trades_category'
#  'Creative / design / arts & media_category'
#  'Customer service / support_category' 'Domestic help_category'
#  'Energy / oil & gas_category' 'Engineering_category'
#  'Facilities / maintenance_category' 'Graduate_category'
#  'Management / exec / consulting_category' 'Manufacturing_category'
#  'Marketing / advertising / PR_category' 'Other / general_category'
#  'Part-time / weekend_category' 'Wholesale and retail_category'
#  'Transport / logistics / warehouse_category' 'Travel / tourism_category'
#  'East Midlands_region' 'East of England_region' 'London_region'
#  'North West_region' 'Northern Ireland_region' 'Scotland_region'
#  'Unknown_region' 'West Midlands_region' 'Yorkshire and The Humber_region'
#  'England_region' 'Manufacturing_Jobs'
#  'Information Media and Telecommunications_Jobs'
#  'Professional, Scientific and Technical Services_Jobs'
#  'Other Services_Jobs' 'Accommodation and Food Services_Sales'
#  'Professional, Scientific and Technical Services_Sales'
#  'Other Services_Sales' 'Agriculture, forestry and fishing (A)_Turnover'
#  'Wholesale and retail; repair of motor vehicles (G)_Turnover'
#  'Accommodation and food services (I)_Turnover'
#  'Professional, scientific and technical activities (M)_Turnover'
#  'Human health and social work (Q)_Turnover'
#  'Other service activities (S)_Turnover' 'Production (B-E)_Exp'
#  'Services (G-T)_Exp' 'Accommodation and food services (I)_Exp'
#  'Information and communication (J)_Exp' 'Real estate activities (L)_Exp'
#  'Professional, scientific and technical activities (M)_Exp'
#  'Education (P)_Exp' 'Construction (F)_Newreporters'
#  'Wholesale and retail; repair of motor vehicles (G)_Newreporters'
#  'Transport and storage (H)_Newreporters'
#  'Other service activities (S)_Newreporters'
#  'Production - Repayment claim' 'A - Tax due' 'B - Tax due' 'D - Tax due'
#  'E - Repayment claim' 'F - Tax due' 'F - Repayment claim'
#  'G - Repayment claim' 'I - Tax due' 'I - Repayment claim' 'J - Tax due'
#  'K - Tax due' 'L - Tax due' 'M - Tax due' 'P - Tax due'
#  'P - Repayment claim' 'R - Tax due' 'S - Repayment claim']

# %%
#Save to csv file
X_BusinessInsights.to_csv(r'X_BusinessInsights.csv',index=False)

# %% [markdown]
# # END
